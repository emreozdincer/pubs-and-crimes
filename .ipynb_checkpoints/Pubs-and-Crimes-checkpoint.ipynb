# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %matplotlib inline

# %%
# Read all .csv files to data relevant frames
df_pubs = pd.read_csv("open_pubs.csv")
df_crimes = pd.read_csv("london_crime_by_lsoa.csv")
df_borough_demographics = pd.read_csv("london-borough-profiles-2016 Data set.csv")

# %%
df_pubs
# Out:
#        fas_id                                      name  \
# 0          24                                Anchor Inn
# 1          30                                 Angel Inn
# 2          63                           Black Boy Hotel
# 3          64                               Black Horse
# 4          65                                Black Lion
# 5          85                              Bristol Arms
# 6         101                       Butt and Oyster Inn
# 7         126                             Carriers Arms
# 8         140                      Chenery Catering Ltd
# 9         153                                 Clubhouse
# 10        154                             Cock And Bell
# 11        197                                 Crown Inn
# 12        230                               Eight Bells
# 13        240                        Exclusive Inns Ltd
# 14        252                            Five Bells Inn
# 15        261                            Fox and Hounds
# 16        272                            Gardeners Arms
# 17        281                     Glemsford Social Club
# 18        294        Grover And Allen (J D Wetherspoon)
# 19        307                           Hare and Hounds
# 20        308                           Hare And Hounds
# 21        396                                Kings Head
# 22        397                            Kings Head Inn
# 23        429                   Long Melford & District
# 24        441                               Maldon Grey
# 25        498                       North Street Tavern
# 26        500                Northcroft Social Club Ltd
# 27        516                    Oyster Reach Beefeater
# 28        535                     Plough And Fleece Inn
# 29        553                           Prince Of Wales
# ...       ...                                       ...
# 51536  514648                       The Black Horse Inn
# 51537  514656                            The Club House
# 51538  514659                            The Commercial
# 51539  514663                         The Crafty Dragon
# 51540  514664                           The Cross Foxes
# 51541  514665                     The Cross Foxes Hotel
# 51542  514667                         The Cunliffe Arms
# 51543  514671                             The Four Dogs
# 51544  514673                       The Gate Hangs High
# 51545  514684                           The Miners Arms
# 51546  514685                          The Mulberry Inn
# 51547  514689            The North and South Wales Bank
# 51548  514693                            The Old Vaults
# 51549  514709                  The Royal British Legion
# 51550  514711                       The Royal Oak Hotel
# 51551  514723                           The Telford Inn
# 51552  514726                                The Vaults
# 51553  514733                             Theatre Stiwt
# 51554  514748                            Tree Tops Club
# 51555  514760                                Turf Hotel
# 51556  514764            Tyn Y Capel Inn and Restaurant
# 51557  514780                               Voodoo Moon
# 51558  514789                           Wetherspoon Plc
# 51559  514791                         White Horse Hotel
# 51560  514800  Wrexham & District War Memorial Club Ltd
# 51561  514806                 Wrexham Lager Social Club
# 51562  514809         Wrexham Rail Sports & Social Club
# 51563  514810                        Wrexham Rugby Club
# 51564  514814                                     Y Tai
# 51565  514817                              Yew Tree Inn
#
#                                                  address  postcode  easting  \
# 0      Upper Street, Stratford St Mary, COLCHESTER, E...   CO7 6LW   604748
# 1           Egremont Street, Glemsford, SUDBURY, Suffolk  CO10 7SA   582888
# 2                        7 Market Hill, SUDBURY, Suffolk  CO10 2EA   587356
# 3      Lower Street, Stratford St Mary, COLCHESTER, E...   CO7 6JS   604270
# 4                 Lion Road, Glemsford, SUDBURY, Suffolk  CO10 7RF   582750
# 5                Bristol Hill, Shotley, IPSWICH, Suffolk   IP9 1PU   624667
# 6         Pin Mill Road, Chelmondiston, IPSWICH, Suffolk   IP9 1JW   620709
# 7           Heath Road, East Bergholt, COLCHESTER, Essex   CO7 6RA   607463
# 8        The Bull Inn, The Street, Brantham, MANNINGTREE  CO11 1PN   612239
# 9      The Grange Caravan Park, Straight Road, East B...   CO7 6UX   609787
# 10           Hall Street, Long Melford, SUDBURY, Suffolk  CO10 9JR   586263
# 11        Cattawade Street, Brantham, MANNINGTREE, Essex  CO11 1RE   610208
# 12     Eight Bells Public House, 90-92 Angel Street, ...   IP7 5DD   602934
# 13       The Swan Inn, The Street, Monks Eleigh, IPSWICH   IP7 7AU   596807
# 14        63 Bures Road, Great Cornard, SUDBURY, Suffolk  CO10 0HU   588335
# 15               Church Street, Groton, SUDBURY, Suffolk  CO10 5ED   595966
# 16           Manningtree Road, Stutton, IPSWICH, Suffolk   IP9 2TG   614019
# 17         25-27 Hunts Hill, Glemsford, SUDBURY, Suffolk  CO10 7RP   582842
# 18     The Grover and Allen, 67-70 North Street, SUDB...  CO10 1RF   587393
# 19         Harrow Street, Leavenheath, COLCHESTER, Essex   CO6 4PW   595658
# 20          Heath Road, East Bergholt, COLCHESTER, Essex   CO7 6RL   607632
# 21          132 High Street, Bildeston, IPSWICH, Suffolk   IP7 7ED   599235
# 22       115 Bures Road, Great Cornard, SUDBURY, Suffolk  CO10 0JE   588371
# 23     Ex-Service & Social Club, Hall Street, Long Me...  CO10 9JL   586344
# 24            Cats Lane, Great Cornard, SUDBURY, Suffolk  CO10 2RZ   588539
# 25                        North Street, SUDBURY, Suffolk  CO10 1RE   587306
# 26                  Flat 1, Croft Road, SUDBURY, Suffolk  CO10 1JD   587183
# 27              Bourne Hill, Wherstead, IPSWICH, Suffolk   IP2 8ND   616088
# 28      Great Green, Cockfield, BURY ST EDMUNDS, Suffolk  IP30 0HJ   591666
# 29                          New Street, SUDBURY, Suffolk  CO10 1JB   587198
# ...                                                  ...       ...      ...
# 51536  The Black Horse Inn, Hall Street, Pen Y Cae, W...  LL14 2RU   328246
# 51537  The Club House, Oak Road, Wrexham Industrial E...  LL13 9RG   339119
# 51538  The Commercial, 11 College Street, Wrexham, LL...  LL13 8LU   333463
# 51539                   29 High Street, Wrexham, Wrexham  LL13 8HY   333567
# 51540  The Cross Foxes, 15 Abbot Street, Wrexham, LL1...  LL11 1TA   333434
# 51541  The Cross Foxes Hotel, High Street, Pentre Bro...  LL11 6AW   330419
# 51542  The Cunliffe Arms, Jeffreys Road, Wrexham, LL1...  LL12 7PG   334370
# 51543         The Four Dogs, Box Lane, Wrexham, LL12 8EF  LL12 8EF   333861
# 51544  The Gate Hangs High, 148 Rhosnesni Lane, Wrexh...  LL13 9ES   334869
# 51545      The Miners Arms, High Street, Brymbo, Wrexham  LL11 5BL   329462
# 51546  The Mulberry Inn, Llwynmawr, Llangollen, LL20 7BB  LL20 7BB   322336
# 51547  The North and South Wales Bank, 14 High Street...  LL13 8HP   333567
# 51548  The Old Vaults, 5 Chester Street, Wrexham, LL1...  LL13 8BD   333610
# 51549  The Royal British Legion, Watts Dyke, Llay, Wr...  LL12 0RL   332987
# 51550  The Royal Oak Hotel, High Street, Bangor Isyco...  LL13 0BU   338893
# 51551  The Telford Inn, Station Road, Trevor, Llangollen  LL20 7TT   327139
# 51552         The Vaults, Bridge Street, Ruabon, Wrexham  LL14 6DA   330245
# 51553  Theatre Stiwt, The Stiwt, Broad Street, Rhosll...  LL14 1RB   329257
# 51554        Tree Tops Club, The Plassey, Eyton, Wrexham  LL13 0SP   335535
# 51555           Turf Hotel, Mold Road, Wrexham, LL11 2AH  LL11 2AH   332822
# 51556  Tyn Y Capel Inn and Restaurant, Church Road, M...  LL11 3DA   326939
# 51557  Voodoo Moon, Central Buildings, Brook Street, ...  LL13 7LH   333360
# 51558  Wetherspoon Plc, The Elihu Yale, 44-46 Regent ...  LL11 1RR   333250
# 51559   White Horse Hotel, High Street, Overton, Wrexham  LL13 0DT   337319
# 51560  Wrexham & District War Memorial Club Ltd, Farn...  LL13 8DE   333909
# 51561  Wrexham Lager Social Club, 1 Union Road, Wrexh...  LL13 7SR   333031
# 51562  Wrexham Rail Sports & Social Club, Pentrefelin...  LL13 7LU   333259
# 51563  Wrexham Rugby Club, Bryn Estyn Road, Wrexham, ...  LL13 9TY   335837
# 51564               Y Tai, Railway Road, Brymbo, Wrexham  LL11 5EA   329598
# 51565       Yew Tree Inn, High Street, Gresford, Wrexham  LL12 8RF   334721
#
#        northing   latitude  longitude local_authority
# 0      234405.0   51.97039   0.979328         Babergh
# 1      247368.0  52.094427   0.668408         Babergh
# 2      241327.0  52.038683   0.730226         Babergh
# 3      233920.0  51.966211   0.972091         Babergh
# 4      248298.0  52.102815   0.666893         Babergh
# 5      233744.0  51.956771   1.268376         Babergh
# 6      237978.0  51.996361   1.213605         Babergh
# 7      235397.0  51.978282   1.019392         Babergh
# 8      234481.0  51.968265   1.088246         Babergh
# 9      235284.0  51.976413   1.053112         Babergh
# 10     245560.0  52.077065    0.71663         Babergh
# 11     233105.0  51.956682   1.057899         Babergh
# 12     242836.0  52.046763   0.957949         Babergh
# 13     247608.0   52.09181   0.871471         Babergh
# 14     240258.0  52.028751   0.743908         Babergh
# 15     241547.0  52.037694   0.855736         Babergh
# 16     234537.0  51.968086   1.114167         Babergh
# 17     247729.0  52.097693   0.667931         Babergh
# 18     241511.0  52.040323    0.73088         Babergh
# 19     237394.0  52.000502   0.848865         Babergh
# 20     235424.0  51.978461   1.021866         Babergh
# 21     249535.0  52.108245    0.90799         Babergh
# 22     240067.0  52.027024   0.744328         Babergh
# 23     245744.0   52.07869   0.717911         Babergh
# 24     241342.0  52.038408   0.747475         Babergh
# 25     241627.0  52.041394   0.729677         Babergh
# 26     241531.0  52.040573   0.727833         Babergh
# 27     241605.0  52.030727   1.148689         Babergh
# 28     256058.0  52.169493   0.801282         Babergh
# 29     241591.0  52.041098   0.728083         Babergh
# ...         ...        ...        ...             ...
# 51536  345219.0  52.999464  -3.070614         Wrexham
# 51537  349220.0  53.036765  -2.909382         Wrexham
# 51538  350167.0   53.04461  -2.993914         Wrexham
# 51539  350205.0  53.044965  -2.992371         Wrexham
# 51540  350218.0  53.045074  -2.994357         Wrexham
# 51541  353308.0  53.072461   -3.03999         Wrexham
# 51542  352486.0  53.065574  -2.980846         Wrexham
# 51543  351943.0  53.060631  -2.988344         Wrexham
# 51544  351420.0  53.056054  -2.973199         Wrexham
# 51545  353894.0  53.077593    -3.0544         Wrexham
# 51546  337050.0  52.925221  -3.156695         Wrexham
# 51547  350234.0  53.045234  -2.992377         Wrexham
# 51548  350279.0  53.045644  -2.991745         Wrexham
# 51549  355359.0  53.091206  -3.002095         Wrexham
# 51550  345490.0  53.003223  -2.912044         Wrexham
# 51551  342324.0  52.973304  -3.086453         Wrexham
# 51552  343767.0  52.986678   -3.04052         Wrexham
# 51553  346510.0  53.011202  -3.055836         Wrexham
# 51554  345465.0  53.002595  -2.962071         Wrexham
# 51555  351058.0  53.052538  -3.003659         Wrexham
# 51556  351868.0  53.059054  -3.091594         Wrexham
# 51557  350160.0  53.044543  -2.995449         Wrexham
# 51558  350462.0  53.047235  -2.997152         Wrexham
# 51559  341904.0   52.97081    -2.9348         Wrexham
# 51560  350438.0  53.047101  -2.987318         Wrexham
# 51561  350563.0  53.048124  -3.000439         Wrexham
# 51562  350213.0  53.044998  -2.996966         Wrexham
# 51563  351156.0   53.05379  -2.958706         Wrexham
# 51564  353894.0  53.077611   -3.05237         Wrexham
# 51565  354974.0   53.08797  -2.976144         Wrexham
#
# [51566 rows x 9 columns]

# %%
df_crimes = df_crimes[df_crimes["borough"] != "City of London"]
number_of_boroughs = len(df_crimes.groupby('borough').count())
df_crimes
# df_crimes.groupby('borough').count()
# Out:
#           lsoa_code                 borough               major_category  \
# 0         E01001116                 Croydon                     Burglary
# 1         E01001646               Greenwich  Violence Against the Person
# 2         E01000677                 Bromley  Violence Against the Person
# 3         E01003774               Redbridge                     Burglary
# 4         E01004563              Wandsworth                      Robbery
# 5         E01001320                  Ealing           Theft and Handling
# 6         E01001342                  Ealing  Violence Against the Person
# 7         E01002633                Hounslow                      Robbery
# 8         E01003496                  Newham              Criminal Damage
# 9         E01004177                  Sutton           Theft and Handling
# 10        E01001985                Haringey           Theft and Handling
# 11        E01003076                 Lambeth  Violence Against the Person
# 12        E01003852    Richmond upon Thames                      Robbery
# 13        E01004547              Wandsworth  Violence Against the Person
# 14        E01002398              Hillingdon           Theft and Handling
# 15        E01002358                Havering  Violence Against the Person
# 16        E01000086    Barking and Dagenham           Theft and Handling
# 17        E01003708               Redbridge  Violence Against the Person
# 18        E01002945    Kingston upon Thames           Theft and Handling
# 19        E01004195                  Sutton                        Drugs
# 20        E01003651               Redbridge  Violence Against the Person
# 21        E01004660             Westminster           Theft and Handling
# 22        E01001786                 Hackney              Criminal Damage
# 23        E01001432                 Enfield                        Drugs
# 24        E01001301                  Ealing           Theft and Handling
# 25        E01001794                 Hackney  Violence Against the Person
# 26        E01002195                  Harrow           Theft and Handling
# 27        E01001201                  Ealing  Violence Against the Person
# 28        E01001972                Haringey  Violence Against the Person
# 29        E01003325                Lewisham  Violence Against the Person
# ...             ...                     ...                          ...
# 13490574  E01002823  Kensington and Chelsea           Theft and Handling
# 13490575  E01004020               Southwark             Fraud or Forgery
# 13490576  E01004270           Tower Hamlets                      Robbery
# 13490577  E01001135                 Croydon              Criminal Damage
# 13490578  E01002659                Hounslow  Violence Against the Person
# 13490579  E01004100                  Sutton                        Drugs
# 13490580  E01003154                 Lambeth                     Burglary
# 13490581  E01000789                 Bromley  Violence Against the Person
# 13490582  E01003452                  Merton                     Burglary
# 13490583  E01002953    Kingston upon Thames              Criminal Damage
# 13490584  E01003301                Lewisham  Violence Against the Person
# 13490585  E01001380                  Ealing  Violence Against the Person
# 13490586  E01004341          Waltham Forest              Sexual Offences
# 13490587  E01000224                  Barnet           Theft and Handling
# 13490588  E01002178                  Harrow  Violence Against the Person
# 13490589  E01003371                  Merton                        Drugs
# 13490590  E01001679               Greenwich           Theft and Handling
# 13490591  E01000193                  Barnet              Criminal Damage
# 13490592  E01033327                Lewisham  Violence Against the Person
# 13490593  E01004531              Wandsworth           Theft and Handling
# 13490594  E01001706               Greenwich              Criminal Damage
# 13490595  E01001144                 Croydon  Violence Against the Person
# 13490596  E01000655                 Bromley           Theft and Handling
# 13490597  E01000588                   Brent           Theft and Handling
# 13490598  E01032577              Hillingdon           Theft and Handling
# 13490599  E01000504                   Brent              Criminal Damage
# 13490600  E01002504              Hillingdon                      Robbery
# 13490601  E01004165                  Sutton                     Burglary
# 13490602  E01001134                 Croydon                      Robbery
# 13490603  E01003413                  Merton  Violence Against the Person
#
#                                   minor_category  value  year  month
# 0                    Burglary in Other Buildings      0  2016     11
# 1                                 Other violence      0  2016     11
# 2                                 Other violence      0  2015      5
# 3                    Burglary in Other Buildings      0  2016      3
# 4                              Personal Property      0  2008      6
# 5                                    Other Theft      0  2012      5
# 6                               Offensive Weapon      0  2010      7
# 7                              Personal Property      0  2013      4
# 8              Criminal Damage To Other Building      0  2013      9
# 9                    Theft/Taking of Pedal Cycle      1  2016      8
# 10        Motor Vehicle Interference & Tampering      0  2013     12
# 11                                Other violence      0  2015      4
# 12                             Personal Property      0  2014      1
# 13                              Offensive Weapon      0  2011     10
# 14                 Theft/Taking Of Motor Vehicle      0  2016      2
# 15                                  Wounding/GBH      0  2012      2
# 16                            Other Theft Person      1  2009      5
# 17                                Common Assault      0  2009      6
# 18                              Theft From Shops      0  2016     11
# 19                           Possession Of Drugs      0  2009     10
# 20                                    Harassment      0  2012      2
# 21                         Handling Stolen Goods      0  2012      2
# 22                   Criminal Damage To Dwelling      0  2011      6
# 23                           Possession Of Drugs      0  2011      5
# 24                            Other Theft Person      2  2012      1
# 25                                    Harassment      1  2013      2
# 26                 Theft/Taking Of Motor Vehicle      0  2012      3
# 27                                Other violence      0  2012     11
# 28                                  Wounding/GBH      0  2015     12
# 29                                Common Assault      0  2016      2
# ...                                          ...    ...   ...    ...
# 13490574  Motor Vehicle Interference & Tampering      0  2016      2
# 13490575                   Other Fraud & Forgery      0  2014     12
# 13490576                       Personal Property      5  2011      3
# 13490577                   Other Criminal Damage      0  2015      4
# 13490578                          Other violence      0  2013      4
# 13490579                        Drug Trafficking      0  2016     12
# 13490580                  Burglary in a Dwelling      3  2015     10
# 13490581                              Harassment      3  2009     12
# 13490582             Burglary in Other Buildings      0  2014      8
# 13490583             Criminal Damage To Dwelling      0  2010      9
# 13490584                     Assault with Injury      1  2015     10
# 13490585                          Common Assault      0  2011     12
# 13490586                                    Rape      0  2008      9
# 13490587           Theft/Taking Of Motor Vehicle      0  2010      8
# 13490588                     Assault with Injury      0  2015      8
# 13490589                     Possession Of Drugs      0  2015      4
# 13490590           Theft/Taking Of Motor Vehicle      1  2012      4
# 13490591                   Other Criminal Damage      0  2016      2
# 13490592                          Common Assault      2  2013      7
# 13490593                   Handling Stolen Goods      0  2014     12
# 13490594       Criminal Damage To Other Building      0  2008      2
# 13490595                              Harassment      0  2012      1
# 13490596                        Theft From Shops      0  2010      7
# 13490597             Theft/Taking of Pedal Cycle      0  2014     10
# 13490598                             Other Theft      0  2012      2
# 13490599             Criminal Damage To Dwelling      0  2015      2
# 13490600                       Personal Property      1  2015      6
# 13490601                  Burglary in a Dwelling      0  2011      2
# 13490602                       Business Property      0  2011      5
# 13490603                            Wounding/GBH      0  2015      6
#
# [13480884 rows x 7 columns]

# %%
df_borough_demographics.head()
# Out:
#         Code   New code             Area name Inner/ Outer London  \
# 0        NaN        NaN                   NaN                 NaN
# 1  E09000001  E09000001        City of London        Inner London
# 2  E09000002  E09000002  Barking and Dagenham        Outer London
# 3  E09000003  E09000003                Barnet        Outer London
# 4  E09000004  E09000004                Bexley        Outer London
#
#   GLA Population Estimate 2016 GLA Household Estimate 2016  \
# 0                          NaN                         NaN
# 1                       8,548                       5,179
# 2                     205,773                      76,841
# 3                     385,108                     149,147
# 4                     243,303                      97,233
#
#   Inland Area (Hectares) Population density (per hectare) 2016  \
# 0                    NaN                                   NaN
# 1                  290.4                                  28.9
# 2                3,610.8                                  57.3
# 3                8,674.8                                  44.5
# 4                6,058.1                                  39.9
#
#    Average Age, 2016  Proportion of population aged 0-15, 2016  \
# 0                NaN                                       NaN
# 1               42.9                                      27.2
# 2               32.9                                      21.0
# 3               37.2                                      21.0
# 4               38.9                                      20.8
#
#                 ...                Happiness score 2011-14 (out of 10)  \
# 0               ...                                                NaN
# 1               ...                                               5.99
# 2               ...                                               7.05
# 3               ...                                               7.37
# 4               ...                                               7.21
#
#    Anxiety score 2011-14 (out of 10) Childhood Obesity Prevalance (%) 2014/15  \
# 0                                NaN                                      NaN
# 1                               5.57                                      n/a
# 2                               3.05                                     25.3
# 3                               2.75                                     18.4
# 4                               3.29                                     21.4
#
#   People aged 17+ with diabetes (%)  \
# 0                               NaN
# 1                               2.6
# 2                               7.3
# 3                               6.0
# 4                               6.9
#
#   Mortality rate from causes considered preventable 2012/14  \
# 0                                                NaN
# 1                                              128.8
# 2                                              227.6
# 3                                              133.8
# 4                                              164.3
#
#   Political control in council  \
# 0                          NaN
# 1                            .
# 2                          Lab
# 3                         Cons
# 4                         Cons
#
#   Proportion of seats won by Conservatives in 2014 election  \
# 0                                                NaN
# 1                                                  .
# 2                                                0.0
# 3                                               50.8
# 4                                               71.4
#
#   Proportion of seats won by Labour in 2014 election  \
# 0                                                NaN
# 1                                                  .
# 2                                              100.0
# 3                                               47.6
# 4                                               23.8
#
#   Proportion of seats won by Lib Dems in 2014 election  \
# 0                                                NaN
# 1                                                  .
# 2                                                0.0
# 3                                                1.6
# 4                                                0.0
#
#   Turnout at 2014 local elections
# 0                             NaN
# 1                               .
# 2                            36.5
# 3                            40.5
# 4                            39.6
#
# [5 rows x 85 columns]

# %%
# Drop null values from borough demographics data frame
df_borough_demographics.dropna(inplace=True) 

# Slice borough names
df_london_boroughs = df_borough_demographics[['Area name']]

# Get list of boroughs in London to an array(list)
borough_list = df_london_boroughs['Area name'].tolist()
df_pubs = df_pubs.rename(columns={'local_authority':'borough'})

# Select all pubs from London, based on the borough names in London
df_london_pubs = df_pubs.loc[df_pubs["borough"].isin(borough_list)]
print ("Pubs that are located in London boroughs:")
df_london_pubs.head()
# Out:
# Pubs that are located in London boroughs:
#       fas_id                           name  \
# 1866   17283       The Three Jolly Wheelers
# 8958   83420                       Aria Bar
# 8959   83454               Barking Arms Ltd
# 8960   83461          Barking football Club
# 8961   83464  Barking Indoor Bowls Club Ltd
#
#                                                 address  postcode  easting  \
# 1866  735 Chigwell Road, Woodford Green, Chigwell, E...   IG8 8AS   542653
# 8958                        31 Longbridge Road, Barking  IG11 8TN   544481
# 8959                      25-27 Station Parade, Barking  IG11 8TU   544404
# 8960      Barking Football Club, Lodge Avenue, Dagenham   RM8 2JR   546614
# 8961  Indoor Bowls Hall, Barking Prk, Longbridge Roa...  IG11 8TA   544692
#
#       northing   latitude longitude               borough
# 1866  192011.0  51.608869  0.058699             Redbridge
# 8958  184425.0   51.54024  0.081962  Barking and Dagenham
# 8959  184344.0  51.539531  0.080819  Barking and Dagenham
# 8960  185058.0  51.545377   0.11296  Barking and Dagenham
# 8961  184653.0  51.542225  0.085096  Barking and Dagenham

# %%
print ("We count the pubs by their unique fas_id's (Food Standard Agency's ID).")
df_pub_count_per_borough = df_london_pubs.groupby("borough").nunique()
df_pub_count_per_borough = df_pub_count_per_borough[["fas_id"]]
df_pub_count_per_borough = df_pub_count_per_borough.rename(columns={'fas_id':'pub_count'})
df_pub_count_per_borough
# Out:
# We count the pubs by their unique fas_id's (Food Standard Agency's ID).
#                         pub_count
# borough
# Barking and Dagenham           41
# Barnet                        139
# Bexley                        125
# Brent                         105
# Bromley                       184
# Camden                        278
# City of London                245
# Croydon                       145
# Ealing                        151
# Enfield                       175
# Greenwich                     122
# Hackney                       197
# Hammersmith and Fulham        135
# Haringey                       98
# Harrow                         85
# Havering                       95
# Hillingdon                    152
# Hounslow                      128
# Islington                     183
# Kensington and Chelsea        110
# Kingston upon Thames          133
# Lambeth                       167
# Lewisham                       72
# Merton                         74
# Newham                         47
# Redbridge                      87
# Richmond upon Thames          156
# Southwark                     203
# Sutton                         44
# Tower Hamlets                   1
# Waltham Forest                 91
# Wandsworth                    172
# Westminster                   385

# %%
df_crimes_per_borough = df_crimes.groupby("borough").count()
df_crimes_per_borough = df_crimes_per_borough [['lsoa_code']]

df_crimes_per_borough
# Out:
#                         lsoa_code
# borough
# Barking and Dagenham       311040
# Barnet                     572832
# Bexley                     385668
# Brent                      490644
# Bromley                    523908
# Camden                     378432
# Croydon                    602100
# Ealing                     549396
# Enfield                    511164
# Greenwich                  421200
# Hackney                    417744
# Hammersmith and Fulham     328752
# Haringey                   413856
# Harrow                     365688
# Havering                   399600
# Hillingdon                 442584
# Hounslow                   395928
# Islington                  359208
# Kensington and Chelsea     296784
# Kingston upon Thames       259524
# Lambeth                    519048
# Lewisham                   485136
# Merton                     339876
# Newham                     471420
# Redbridge                  445716
# Richmond upon Thames       304128
# Southwark                  483300
# Sutton                     322488
# Tower Hamlets              412128
# Waltham Forest             406296
# Wandsworth                 498636
# Westminster                366660

# %%
df_pubs_crimes = df_crimes_per_borough.join(df_pub_count_per_borough)
# print(df_crimes_per_borough)
# df_crimes_per_borough
# plt.plot(df_crimes_per_borough)
# # ax.set_xticks(range(number_of_boroughs))
# plt.xlabel('Boroughs')
# plt.xticks(rotation=90)
# plt.ylabel('Number of Crimes Committed')

ax = df_pubs_crimes.plot(secondary_y='pub_count', rot=90)
ax.set_xticklabels(borough_list)
ax2 = ax.twinx()
ax2.set_yscale('log')


# plt.show()
